# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("combined_data.csv", header=0)
df.head()
# Out:
#    cited_by_fbwalls_count  cited_by_feeds_count  cited_by_gplus_count  \
# 0                       4                     1                     0
# 1                       6                     0                     0
# 2                       5                    13                     2
# 3                      14                    17                    10
# 4                       0                     2                     0
#
#    cited_by_msm_count  cited_by_posts_count  cited_by_rdts_count  \
# 0                   1                    33                    0
# 1                   0                    85                    0
# 2                   7                    76                    0
# 3                 108                   535                    1
# 4                   0                    13                    0
#
#    cited_by_tweeters_count  cited_by_videos_count  \
# 0                       16                      4
# ...
