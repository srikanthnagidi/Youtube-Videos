# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("combined_data.csv", header=0)
df.head()
# Out:
#    cited_by_fbwalls_count  cited_by_feeds_count  cited_by_gplus_count  \
# 0                       4                     1                     0
# 1                       6                     0                     0
# 2                       5                    13                     2
# 3                      14                    17                    10
# 4                       0                     2                     0
#
#    cited_by_msm_count  cited_by_posts_count  cited_by_rdts_count  \
# 0                   1                    33                    0
# 1                   0                    85                    0
# 2                   7                    76                    0
# 3                 108                   535                    1
# 4                   0                    13                    0
#
#    cited_by_tweeters_count  cited_by_videos_count  \
# 0                       16                      4
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
req = requests.get("https://www.youtube.com/watch?v=dqw4w9wgxcq")
bs = BeautifulSoup(req.text, "html.parser")

# %%
print(bs)
# Out:
# <!DOCTYPE html>
# ...

# %%
for e in elements.keys():
    print(elements[e])
# Out:
# early-body

# %%
from lxml import html
tree = html.fromstring(req.content)

# %%
e = tree.xpath('//div[@id = "info" and @class = "reason style-scope yt-player-error-message-renderer"]')
len(e)
# Out:
# 0

# %%
e = bs.find_all("div")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-129a7b360bc7> in <module>
# ----> 1 e = bs.find_all("div").attrs
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'attrs'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
i=0
for x in e:
    print(i, x)
    i += 1
# Out:
# 0 <div id="early-body"></div>
# 1 <div id="body-container"><div id="a11y-announcements-container" role="alert"><div id="a11y-announcements-message"></div></div><form action="/logout" method="POST" name="logoutForm"><input name="action_logout" type="hidden" value="1"/></form><div id="masthead-positioner"> <div id="ticker-content">
# </div>
# <div class="clearfix yt-base-gutter" id="yt-masthead-container"> <button class="skip-nav" data-target-id="main" id="a11y-skip-nav" tabindex="3">
# Skip navigation
#   </button>
# ...

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException, TimeoutException, ElementNotInteractableException
from selenium.webdriver.support import expected_conditions as EC

df = pd.read_csv("unique_ids.csv", header=0)
df.head()
# Out:
#    youtube_ids
# 0  2iqRF6mWj-A
# 1  42lNiOVFrhc
# 2  2Oag2IpeUjc
# 3  7Csem3LocpQ
# 4  GxiDNGKZZno

# %%
driver = webdriver.Chrome("C:/ProgramData/chocolatey/bin/chromedriver.exe")
driver.maximize_window()

# %%
driver.get("https://www.youtube.com/watch?v=9nPTDYqGcdE")

# %%
elements = driver.find_element_by_xpath('//ytd-watch-flexy')

# %%
elements.text
# Out:
# 'This video is unavailable.'
